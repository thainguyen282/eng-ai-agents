# %%
from ultralytics import YOLO
import torch
import cv2
import numpy as np
from filterpy.kalman import KalmanFilter
from PIL import Image

# Load the YOLOv8 model (pre-trained on COCO dataset)
model = YOLO("yolov8x.pt")  # You can use yolov8s, yolov8m, or yolov8l for better accuracy
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Define input and output video
video_path = "video.mp4"
output_path = "output_kaman_filter.avi"

# Set up video capture
cap = cv2.VideoCapture(video_path)
fps = int(cap.get(cv2.CAP_PROP_FPS))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define the output video writer
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# %%
def KalManInitialize():
    kf = KalmanFilter(dim_x=4, dim_z=2)
    # kf.x = np.array([0, 0, 0, 0])
    dt = 1 / 30  
    kf.F = np.array([[1, 0, dt, 0],
                    [0, 1, 0, dt],
                    [0, 0, 1, 0],
                    [0, 0, 0, 1]])
    kf.H = np.array([[1, 0, 0, 0],
                    [0, 1, 0, 0]])
    np.eye(2, dtype=np.float32) * 0.5
    kf.Q = np.eye(4, dtype=np.float32) * 0.03 
    return kf

# %%
def to_tensor(frame):
    # Convert the frame (BGR) to RGB
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Convert to tensor and normalize to [0, 1] range
    frame_tensor = torch.tensor(frame_rgb).permute(2, 0, 1).unsqueeze(0).float() / 255.0
    
    # Convert the tensor to uint8 (0-255 range)
    frame_tensor_uint8 = (frame_tensor * 255).clamp(0, 255).byte()
    
    return frame_tensor_uint8

def run_model(frame) -> tuple:
    CONFIDENCE_THRESHOLD_LIMIT = 0.3
    model.to(device)
    batch = [frame]
    centroid_x = None
    centroid_y = None
    with torch.no_grad():
        result = model(batch, device=device)[0]

    bboxes = np.array(result.boxes.xyxy.cpu(), dtype="int")
    classes = np.array(result.boxes.cls.cpu(), dtype="int")
    confidence = np.array(result.boxes.conf.cpu(), dtype="float")
    BOX_COLOUR = (37, 245, 75)
    for cls, bbox, conf in zip(classes, bboxes, confidence):
        (x, y, x2, y2) = bbox
        object_name = model.names[cls]
        if conf < CONFIDENCE_THRESHOLD_LIMIT:
            continue
        if object_name != "truck" and object_name != "car": 
            continue
        centroid_x = (x + x2) // 2
        centroid_y = (y + y2) // 2
        cv2.circle(frame, (centroid_x, centroid_y), 5, BOX_COLOUR, -1)
        cv2.rectangle(frame, (x, y), (x2, y2), BOX_COLOUR, 2)

    return centroid_x, centroid_y

# %%
kf = KalManInitialize()

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    if kf.x is not None:
        predicted = kf.predict()
        predicted_x = int(kf.x[0])
        predicted_y = int(kf.x[1])
        predicted_dx, predicted_dy = kf.x[2:]  # Predicted velocity
        print(predicted_x, predicted_y)
        print(f"Predicted velocity: (dx: {predicted_dx}, dy: {predicted_dy})")

    updated_frame = run_model(frame)
    
    
    if updated_frame != (None, None):
        measured_x, measured_y = updated_frame
        kf.update(np.array([[np.float32(measured_x)], [np.float32(measured_y)]]))
        cv2.circle(frame, (measured_x, measured_y), 6, (0, 255, 0), 2)
    cv2.circle(frame, (predicted_x, predicted_y), 8, (0, 0, 255), 2) 
    out.write(frame)
    if cv2.waitKey(1) == ord("q"):
        break
cap.release()
out.release()
cv2.destroyAllWindows()

print("Video processing complete. Output saved at:", output_path)
# Out:
# /tmp/ipykernel_2828480/207223266.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_x = int(kf.x[0])
# /tmp/ipykernel_2828480/207223266.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   predicted_y = int(kf.x[1])
# 0 0
# Predicted velocity: (dx: [          0], dy: [          0])
#
# 0: 640x384 1 car, 1 truck, 9.2ms
# Speed: 2.3ms preprocess, 9.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 186 411
# Predicted velocity: (dx: [     6.0066], dy: [     13.293])
#
# 0: 640x384 1 car, 1 truck, 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 249 551
# Predicted velocity: (dx: [     11.936], dy: [     26.383])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 282 625
# Predicted velocity: (dx: [     17.676], dy: [     39.203])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 303 670
# Predicted velocity: (dx: [     23.184], dy: [     51.228])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 317 703
# Predicted velocity: (dx: [      28.29], dy: [     62.536])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 329 727
# Predicted velocity: (dx: [     33.007], dy: [     72.773])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 337 746
# Predicted velocity: (dx: [     37.172], dy: [     81.808])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 344 761
# Predicted velocity: (dx: [      40.75], dy: [     89.446])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 350 773
# Predicted velocity: (dx: [      43.73], dy: [     95.668])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 355 783
# Predicted velocity: (dx: [      46.26], dy: [     100.78])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 359 792
# Predicted velocity: (dx: [     48.215], dy: [      104.7])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 363 799
# Predicted velocity: (dx: [     49.788], dy: [     107.51])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 366 804
# Predicted velocity: (dx: [     50.858], dy: [     109.17])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 368 809
# Predicted velocity: (dx: [     51.483], dy: [     109.81])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 370 812
# Predicted velocity: (dx: [     51.886], dy: [     109.59])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 372 815
# Predicted velocity: (dx: [     51.934], dy: [      108.8])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 374 817
# Predicted velocity: (dx: [     51.851], dy: [     107.21])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 375 818
# Predicted velocity: (dx: [     51.491], dy: [      105.3])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 376 820
# Predicted velocity: (dx: [     51.075], dy: [     103.31])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 377 820
# Predicted velocity: (dx: [     50.446], dy: [     100.92])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 378 821
# Predicted velocity: (dx: [     49.817], dy: [     98.411])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 379 821
# Predicted velocity: (dx: [     49.022], dy: [     95.465])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 380 820
# Predicted velocity: (dx: [     48.097], dy: [     92.188])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 380 820
# Predicted velocity: (dx: [     47.074], dy: [     89.003])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 380 819
# Predicted velocity: (dx: [     46.147], dy: [     85.745])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 381 818
# Predicted velocity: (dx: [     45.134], dy: [     82.618])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 817
# Predicted velocity: (dx: [     44.059], dy: [     79.448])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 381 817
# Predicted velocity: (dx: [      42.94], dy: [     76.431])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 381 816
# Predicted velocity: (dx: [     41.792], dy: [      73.39])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 382 815
# Predicted velocity: (dx: [     40.629], dy: [     70.514])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 382 814
# Predicted velocity: (dx: [      39.46], dy: [     67.623])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 382 813
# Predicted velocity: (dx: [     38.293], dy: [     64.904])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 381 812
# Predicted velocity: (dx: [     37.135], dy: [      62.34])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 812
# Predicted velocity: (dx: [     35.991], dy: [      60.08])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 811
# Predicted velocity: (dx: [     34.865], dy: [     57.753])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 811
# Predicted velocity: (dx: [      33.76], dy: [     55.711])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 810
# Predicted velocity: (dx: [     32.516], dy: [     53.749])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 380 809
# Predicted velocity: (dx: [     31.166], dy: [       51.7])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 380 809
# Predicted velocity: (dx: [     29.899], dy: [     49.918])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 379 809
# Predicted velocity: (dx: [     28.708], dy: [     48.199])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 379 808
# Predicted velocity: (dx: [     27.585], dy: [     46.542])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 379 808
# Predicted velocity: (dx: [     26.363], dy: [     44.945])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 378 808
# Predicted velocity: (dx: [     25.065], dy: [     43.404])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 377 807
# Predicted velocity: (dx: [     23.876], dy: [     41.918])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 377 807
# Predicted velocity: (dx: [      22.62], dy: [     40.485])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 376 807
# Predicted velocity: (dx: [     21.477], dy: [     39.263])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 375 807
# Predicted velocity: (dx: [     20.272], dy: [     38.218])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 374 807
# Predicted velocity: (dx: [     18.864], dy: [     37.005])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 373 807
# Predicted velocity: (dx: [     17.617], dy: [      36.14])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 372 807
# Predicted velocity: (dx: [      16.19], dy: [     35.244])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 371 807
# Predicted velocity: (dx: [     14.942], dy: [     34.327])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 370 807
# Predicted velocity: (dx: [     13.687], dy: [     33.398])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 369 807
# Predicted velocity: (dx: [     12.434], dy: [     32.465])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 368 807
# Predicted velocity: (dx: [     11.189], dy: [     31.533])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 367 807
# Predicted velocity: (dx: [     10.116], dy: [     30.766])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 366 808
# Predicted velocity: (dx: [     8.8711], dy: [     29.978])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 365 808
# Predicted velocity: (dx: [     7.9685], dy: [     29.337])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 364 808
# Predicted velocity: (dx: [     6.8747], dy: [      28.66])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 363 808
# Predicted velocity: (dx: [     5.9472], dy: [     28.115])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 362 808
# Predicted velocity: (dx: [     4.8441], dy: [     27.207])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 361 808
# Predicted velocity: (dx: [     3.7619], dy: [     26.324])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 360 808
# Predicted velocity: (dx: [     2.7022], dy: [     25.466])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 359 807
# Predicted velocity: (dx: [     1.5091], dy: [     24.475])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 358 807
# Predicted velocity: (dx: [    0.52852], dy: [     23.539])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 356 807
# Predicted velocity: (dx: [   -0.43106], dy: [     22.967])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 356 807
# Predicted velocity: (dx: [    -1.2111], dy: [     22.223])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 355 807
# Predicted velocity: (dx: [    -1.8406], dy: [     21.342])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 354 806
# Predicted velocity: (dx: [    -2.5015], dy: [     20.512])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 353 806
# Predicted velocity: (dx: [    -3.0273], dy: [     19.728])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 352 806
# Predicted velocity: (dx: [    -3.5973], dy: [     18.828])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 352 805
# Predicted velocity: (dx: [    -4.0432], dy: [     17.996])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 805
# Predicted velocity: (dx: [    -4.3856], dy: [     17.223])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 805
# Predicted velocity: (dx: [    -4.4848], dy: [     16.503])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# 351 805
# Predicted velocity: (dx: [    -4.5422], dy: [     15.829])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [    -4.4083], dy: [     15.353])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [    -4.2761], dy: [     14.885])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [    -4.1459], dy: [     14.426])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [     -4.018], dy: [     13.819])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [    -3.7358], dy: [     13.408])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [    -3.4862], dy: [     13.004])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 351 804
# Predicted velocity: (dx: [    -3.1076], dy: [     12.762])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 352 804
# Predicted velocity: (dx: [    -2.7826], dy: [     12.499])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 352 805
# Predicted velocity: (dx: [    -2.3462], dy: [     12.375])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 353 805
# Predicted velocity: (dx: [    -1.8213], dy: [      12.21])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 353 805
# Predicted velocity: (dx: [    -1.3837], dy: [     12.011])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 354 805
# Predicted velocity: (dx: [    -1.0195], dy: [     11.943])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 354 806
# Predicted velocity: (dx: [   -0.56047], dy: [     11.825])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 355 806
# Predicted velocity: (dx: [   -0.18314], dy: [     11.667])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 355 806
# Predicted velocity: (dx: [    0.28223], dy: [     11.478])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 356 806
# Predicted velocity: (dx: [    0.66034], dy: [      11.42])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 356 807
# Predicted velocity: (dx: [     1.1219], dy: [     11.469])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 357 807
# Predicted velocity: (dx: [     1.4926], dy: [      11.45])
#
# 0: 640x384 1 car, 8.7ms
# Speed: 0.9ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 357 807
# Predicted velocity: (dx: [     1.7871], dy: [     11.374])
#
# 0: 640x384 1 car, 1 truck, 8.7ms
# Speed: 0.9ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 357 808
# Predicted velocity: (dx: [      2.018], dy: [     11.253])
#
# 0: 640x384 1 car, 1 truck, 8.7ms
# Speed: 0.9ms preprocess, 8.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 358 808
# Predicted velocity: (dx: [     2.3524], dy: [     11.252])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 358 808
# Predicted velocity: (dx: [     2.6129], dy: [      10.88])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 359 808
# Predicted velocity: (dx: [     2.9683], dy: [     10.676])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 359 808
# Predicted velocity: (dx: [     3.0862], dy: [      10.14])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 359 807
# Predicted velocity: (dx: [     3.3228], dy: [     9.6509])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 360 807
# Predicted velocity: (dx: [     3.4984], dy: [     9.0447])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 360 807
# Predicted velocity: (dx: [       3.78], dy: [     8.5029])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 361 806
# Predicted velocity: (dx: [     3.9899], dy: [     7.8602])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 361 806
# Predicted velocity: (dx: [     4.2969], dy: [     7.1383])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 362 805
# Predicted velocity: (dx: [     4.6814], dy: [     6.6688])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 362 805
# Predicted velocity: (dx: [     4.9706], dy: [     5.9379])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 363 804
# Predicted velocity: (dx: [     5.3371], dy: [     5.1543])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 363 803
# Predicted velocity: (dx: [     5.6082], dy: [     4.4881])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 364 803
# Predicted velocity: (dx: [     5.9566], dy: [     3.9213])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 364 802
# Predicted velocity: (dx: [     6.2098], dy: [      3.282])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 365 801
# Predicted velocity: (dx: [     6.5404], dy: [     2.5869])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 366 801
# Predicted velocity: (dx: [     6.9324], dy: [     2.0063])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 366 800
# Predicted velocity: (dx: [      7.216], dy: [     1.6788])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 367 800
# Predicted velocity: (dx: [     7.5663], dy: [     1.4028])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 367 800
# Predicted velocity: (dx: [     7.8125], dy: [     1.1704])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 368 800
# Predicted velocity: (dx: [     8.1291], dy: [     1.1312])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 369 800
# Predicted velocity: (dx: [     8.5014], dy: [     1.0933])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 370 800
# Predicted velocity: (dx: [     8.9173], dy: [     1.0567])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 370 800
# Predicted velocity: (dx: [       9.21], dy: [     1.1778])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 371 800
# Predicted velocity: (dx: [     9.5572], dy: [     1.4268])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 372 801
# Predicted velocity: (dx: [     9.7906], dy: [     1.6226])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 372 801
# Predicted velocity: (dx: [     10.086], dy: [     1.7738])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 373 801
# Predicted velocity: (dx: [     10.275], dy: [      1.888])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 373 801
# Predicted velocity: (dx: [     10.375], dy: [     1.9712])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 374 801
# Predicted velocity: (dx: [     10.716], dy: [     1.8724])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 375 801
# Predicted velocity: (dx: [     10.782], dy: [     2.0949])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 375 801
# Predicted velocity: (dx: [     10.935], dy: [      2.109])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 376 802
# Predicted velocity: (dx: [      11.16], dy: [      2.266])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 376 802
# Predicted velocity: (dx: [     11.285], dy: [     2.2258])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 377 802
# Predicted velocity: (dx: [     11.329], dy: [     2.1814])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 377 802
# Predicted velocity: (dx: [     11.461], dy: [     2.1338])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 377 802
# Predicted velocity: (dx: [     11.353], dy: [     2.0839])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 378 802
# Predicted velocity: (dx: [     11.362], dy: [     2.1887])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 378 802
# Predicted velocity: (dx: [     11.311], dy: [     2.1064])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 378 802
# Predicted velocity: (dx: [     11.209], dy: [     1.8718])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 379 802
# Predicted velocity: (dx: [     11.068], dy: [     1.6706])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 379 802
# Predicted velocity: (dx: [     10.896], dy: [     1.6543])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 379 801
# Predicted velocity: (dx: [     10.698], dy: [     1.4758])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 379 802
# Predicted velocity: (dx: [     10.637], dy: [      1.479])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 379 802
# Predicted velocity: (dx: [     10.532], dy: [      1.474])
#
# 0: 640x384 1 bus, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 380 802
# Predicted velocity: (dx: [     10.532], dy: [      1.474])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 380 802
# Predicted velocity: (dx: [     10.487], dy: [     1.4515])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 380 801
# Predicted velocity: (dx: [     10.394], dy: [     1.2546])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 380 802
# Predicted velocity: (dx: [     10.264], dy: [     1.2621])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 802
# Predicted velocity: (dx: [     10.269], dy: [     1.2611])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 381 802
# Predicted velocity: (dx: [     10.218], dy: [     1.2536])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 381 802
# Predicted velocity: (dx: [     10.123], dy: [     1.2409])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 382 802
# Predicted velocity: (dx: [     9.9927], dy: [     1.3822])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 382 802
# Predicted velocity: (dx: [     9.8352], dy: [     1.4893])
#
# 0: 640x384 1 bus, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 382 802
# Predicted velocity: (dx: [     9.6559], dy: [     1.5684])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 382 802
# Predicted velocity: (dx: [     9.6559], dy: [     1.5684])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 382 803
# Predicted velocity: (dx: [     9.5527], dy: [     1.8031])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 383 803
# Predicted velocity: (dx: [     9.5922], dy: [     2.1409])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 383 804
# Predicted velocity: (dx: [     9.5694], dy: [     2.5558])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 383 804
# Predicted velocity: (dx: [     9.6625], dy: [     2.7048])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 384 804
# Predicted velocity: (dx: [     9.6847], dy: [     2.8088])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 384 804
# Predicted velocity: (dx: [     9.6512], dy: [     2.8772])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 384 804
# Predicted velocity: (dx: [     9.7313], dy: [     2.9172])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 385 805
# Predicted velocity: (dx: [     9.7452], dy: [     2.9343])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 385 805
# Predicted velocity: (dx: [     9.8623], dy: [     3.0896])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 386 805
# Predicted velocity: (dx: [     10.063], dy: [     3.1998])
#
# 0: 640x384 1 car, 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 386 805
# Predicted velocity: (dx: [     10.173], dy: [     3.2728])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 387 806
# Predicted velocity: (dx: [     10.367], dy: [     3.4716])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 387 806
# Predicted velocity: (dx: [      10.47], dy: [     3.6156])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 388 806
# Predicted velocity: (dx: [     10.657], dy: [     3.7141])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 389 806
# Predicted velocity: (dx: [     10.909], dy: [     3.6188])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 389 806
# Predicted velocity: (dx: [     11.215], dy: [     3.5222])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 390 806
# Predicted velocity: (dx: [     11.406], dy: [     3.5814])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 391 806
# Predicted velocity: (dx: [     11.659], dy: [      3.611])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 391 807
# Predicted velocity: (dx: [     11.804], dy: [     3.7728])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 392 807
# Predicted velocity: (dx: [     12.017], dy: [     4.0415])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 393 808
# Predicted velocity: (dx: [     12.285], dy: [     4.3961])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 393 808
# Predicted velocity: (dx: [     12.596], dy: [      4.506])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 394 808
# Predicted velocity: (dx: [     12.941], dy: [     4.5721])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 395 808
# Predicted velocity: (dx: [     13.154], dy: [     4.4458])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 396 808
# Predicted velocity: (dx: [     13.416], dy: [      4.476])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 396 808
# Predicted velocity: (dx: [     13.717], dy: [     4.3208])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 397 808
# Predicted velocity: (dx: [     14.047], dy: [     4.1717])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 398 809
# Predicted velocity: (dx: [     14.399], dy: [     4.1848])
#
# 0: 640x384 1 car, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 399 809
# Predicted velocity: (dx: [     14.924], dy: [     4.3301])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 400 809
# Predicted velocity: (dx: [     15.275], dy: [     4.4261])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 401 810
# Predicted velocity: (dx: [     15.638], dy: [     4.6377])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 402 810
# Predicted velocity: (dx: [     16.009], dy: [     5.0992])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 403 810
# Predicted velocity: (dx: [     16.384], dy: [     5.1361])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 404 811
# Predicted velocity: (dx: [     16.762], dy: [     5.1394])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 405 811
# Predicted velocity: (dx: [     16.982], dy: [     5.5847])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 406 812
# Predicted velocity: (dx: [      17.23], dy: [     6.0753])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 407 813
# Predicted velocity: (dx: [     17.498], dy: [     6.6003])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 408 814
# Predicted velocity: (dx: [     17.783], dy: [     6.9941])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 409 815
# Predicted velocity: (dx: [     18.078], dy: [     7.7484])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 410 816
# Predicted velocity: (dx: [     18.382], dy: [     8.4797])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 411 817
# Predicted velocity: (dx: [      18.69], dy: [      9.032])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 412 818
# Predicted velocity: (dx: [     19.157], dy: [     9.4355])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 413 819
# Predicted velocity: (dx: [     19.438], dy: [     9.8719])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 414 819
# Predicted velocity: (dx: [     19.722], dy: [      10.02])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 415 819
# Predicted velocity: (dx: [     20.007], dy: [     10.088])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 416 820
# Predicted velocity: (dx: [     20.449], dy: [     10.092])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 417 820
# Predicted velocity: (dx: [     20.859], dy: [     10.198])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 418 820
# Predicted velocity: (dx: [     21.241], dy: [     10.075])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 420 821
# Predicted velocity: (dx: [     21.755], dy: [     9.9227])
#
# 0: 640x384 1 car, 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 421 821
# Predicted velocity: (dx: [     22.217], dy: [     9.9029])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 422 821
# Predicted velocity: (dx: [     22.634], dy: [     9.9915])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 423 822
# Predicted velocity: (dx: [     23.013], dy: [     10.012])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 425 822
# Predicted velocity: (dx: [     23.515], dy: [     9.8195])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 426 822
# Predicted velocity: (dx: [     23.959], dy: [     9.9244])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 427 823
# Predicted velocity: (dx: [     24.352], dy: [     10.115])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 428 823
# Predicted velocity: (dx: [     24.702], dy: [     10.217])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 430 823
# Predicted velocity: (dx: [     25.172], dy: [     10.091])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 431 824
# Predicted velocity: (dx: [     25.737], dy: [     10.092])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 433 824
# Predicted velocity: (dx: [      26.22], dy: [      10.04])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 434 825
# Predicted velocity: (dx: [     26.634], dy: [     10.258])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 436 825
# Predicted velocity: (dx: [     27.145], dy: [     10.226])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 437 825
# Predicted velocity: (dx: [     27.734], dy: [     10.147])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 439 825
# Predicted velocity: (dx: [     28.226], dy: [     10.029])
#
# 0: 640x384 1 truck, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 441 825
# Predicted velocity: (dx: [     28.793], dy: [     9.7245])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 442 825
# Predicted velocity: (dx: [     29.262], dy: [     9.2688])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 443 825
# Predicted velocity: (dx: [     29.648], dy: [     8.6922])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 445 824
# Predicted velocity: (dx: [     29.965], dy: [     8.0201])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 446 824
# Predicted velocity: (dx: [     30.224], dy: [       7.43])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 448 824
# Predicted velocity: (dx: [     30.747], dy: [     7.0663])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 449 823
# Predicted velocity: (dx: [     31.169], dy: [     6.4199])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 451 822
# Predicted velocity: (dx: [     31.664], dy: [     5.7026])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 453 822
# Predicted velocity: (dx: [     32.216], dy: [     5.4007])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 454 822
# Predicted velocity: (dx: [     32.811], dy: [     5.1262])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 456 822
# Predicted velocity: (dx: [     33.282], dy: [     4.8755])
#
# 0: 640x384 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 458 821
# Predicted velocity: (dx: [     33.648], dy: [     4.3327])
#
# 0: 640x384 1 car, 1 truck, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 459 821
# Predicted velocity: (dx: [     34.085], dy: [     4.1802])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 461 821
# Predicted velocity: (dx: [     34.576], dy: [      4.034])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 463 821
# Predicted velocity: (dx: [     34.953], dy: [     3.8937])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 464 821
# Predicted velocity: (dx: [     35.391], dy: [      3.759])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 466 821
# Predicted velocity: (dx: [     35.877], dy: [     3.7859])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 468 822
# Predicted velocity: (dx: [     36.399], dy: [     3.9445])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 470 821
# Predicted velocity: (dx: [     36.948], dy: [     3.5841])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 472 821
# Predicted velocity: (dx: [      37.36], dy: [     3.2713])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 473 821
# Predicted velocity: (dx: [     37.657], dy: [     2.8427])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 475 820
# Predicted velocity: (dx: [     38.016], dy: [     2.4782])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 476 820
# Predicted velocity: (dx: [     38.267], dy: [     2.3244])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 478 820
# Predicted velocity: (dx: [     38.586], dy: [     2.1868])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 480 820
# Predicted velocity: (dx: [       38.8], dy: [     2.0631])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 481 820
# Predicted velocity: (dx: [      38.93], dy: [     1.6386])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 482 819
# Predicted velocity: (dx: [     38.989], dy: [     1.2838])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 484 819
# Predicted velocity: (dx: [      38.99], dy: [    0.98761])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 485 819
# Predicted velocity: (dx: [       39.1], dy: [    0.74086])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 487 819
# Predicted velocity: (dx: [     39.143], dy: [     0.5357])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 488 818
# Predicted velocity: (dx: [     39.287], dy: [    0.36555])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 489 818
# Predicted velocity: (dx: [     39.355], dy: [    0.38128])
#
# 0: 640x384 1 car, 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 491 818
# Predicted velocity: (dx: [     39.363], dy: [    0.23568])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 492 818
# Predicted velocity: (dx: [      39.32], dy: [    0.11568])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# 493 818
# Predicted velocity: (dx: [     39.393], dy: [    0.17362])
#
# 0: 640x384 1 car, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 495 818
# Predicted velocity: (dx: [     39.403], dy: [    0.21998])
#
# ...
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 529 851
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.1ms
# Speed: 1.3ms preprocess, 9.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 529 851
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 529 852
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 530 852
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 530 852
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 530 853
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 531 853
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 531 853
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 531 854
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 531 854
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 532 854
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 532 854
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 532 855
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 533 855
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 533 855
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 533 856
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 533 856
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 534 856
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 534 857
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 534 857
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 535 857
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 1 boat, 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# 535 858
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 535 858
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 536 858
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 536 859
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 536 859
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 536 859
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 537 859
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 537 860
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 537 860
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 538 860
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 538 861
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 538 861
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 539 861
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 539 862
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.3ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 539 862
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 539 862
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 540 863
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 540 863
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 540 863
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 541 863
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 541 864
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 541 864
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 541 864
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 542 865
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 542 865
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 542 865
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 543 866
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 543 866
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 543 866
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 544 867
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 544 867
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 544 867
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 544 868
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 545 868
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 545 868
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 545 868
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 546 869
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 546 869
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 546 869
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 547 870
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 547 870
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 547 870
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 547 871
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 548 871
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 548 871
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.0ms
# Speed: 1.2ms preprocess, 9.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 548 872
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 549 872
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 549 872
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 549 873
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 549 873
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 550 873
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 550 873
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 550 874
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 551 874
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 551 874
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 551 875
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 552 875
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 9.1ms
# Speed: 1.2ms preprocess, 9.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 552 875
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.2ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# 552 876
# Predicted velocity: (dx: [     8.8862], dy: [     9.3497])
#
# 0: 640x384 (no detections), 8.9ms
# Speed: 1.1ms preprocess, 8.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# Video processing complete. Output saved at: output_kaman_filter.avi
